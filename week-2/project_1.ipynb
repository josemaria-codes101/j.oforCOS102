# %% [markdown]
# #A
# INPUT item prices
# COMPUTE subtotal
# PRINT subtotal
# PROCESS payment
# PRINT receipt
# UPDATE inventory

# %% [markdown]
# #B21

# %% [markdown]
# #C
# INPUT name1
# INPUT name2
# INPUT age1
# INPUT age2
# LET temp = age1
# LET age1 = age2
# LET age2 = temp
# PRINT age1
# PRINT age2
