# %% [markdown]
# #A
# INPUT item prices
# COMPUTE subtotal
# PRINT subtotal
# PROCESS payment
# PRINT receipt
# UPDATE inventory

# %% [markdown]
# ![1A Flowchart](<Project 1A Flowchart.png>)

# %% [markdown]
# ![1B Flowchart](<Project 1B Flowchart.png>)

# %% [markdown]
# #C
# INPUT name1
# INPUT name2
# INPUT age1
# INPUT age2
# LET temp = age1
# LET age1 = age2
# LET age2 = temp
# PRINT age1
# PRINT age2
