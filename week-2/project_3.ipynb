# %%
# Student Information

names = ["Evelyn","Jessica","Somto","Edith","Liza","Madonna","Waje","Tola","Aisha","Latifa",
"Chinedu","Liam","Wale","Gbenga","Abiola","Kola","Kunle","George","Thomas","Wesley"]

ages = [17,16,17,18,16,18,17,20,19,17,
19,16,18,17,20,19,16,18,17,19]

heights = [5.5,6.0,5.4,5.9,5.6,5.5,6.1,6.0,5.7,5.5,
5.7,5.9,5.8,6.1,5.9,5.5,6.1,5.4,5.8,5.7]

scores = [80,85,70,60,76,66,87,95,50,49,
74,87,75,68,66,78,87,98,54,60]

genders = ['F','F','F','F','F','F','F','F','F','F','M','M','M','M','M','M','M','M','M','M']

print("Name\tAge\tHeight\tScore\tGender")
print("---------------------------------------")

for i in range(len(names)):
    print(f"{names[i]}\t{ages[i]}\t{heights[i]}\t{scores[i]}\t{genders[i]}")
# Out:
# Name	Age	Height	Score	Gender
# ---------------------------------------
# Evelyn	17	5.5	80	F
# Jessica	16	6.0	85	F
# Somto	17	5.4	70	F
# Edith	18	5.9	60	F
# Liza	16	5.6	76	F
# Madonna	18	5.5	66	F
# Waje	17	6.1	87	F
# Tola	20	6.0	95	F
# Aisha	19	5.7	50	F
# Latifa	17	5.5	49	F
# Chinedu	19	5.7	74	M
# Liam	16	5.9	87	M
# Wale	18	5.8	75	M
# Gbenga	17	6.1	68	M
# Abiola	20	5.9	66	M
# Kola	19	5.5	78	M
# Kunle	16	6.1	87	M
# George	18	5.4	98	M
# Thomas	17	5.8	54	M
# Wesley	19	5.7	60	M

# %% [markdown]
# Algorithm: Student Data Table
#
# Start
#
# Create five lists:
#
# Names
#
# Ages
#
# Heights
#
# Scores
#
# Genders
#
# Store the data of all 20 students in the lists.
#
# Display the table header:
#
# Name | Age | Height | Score | Gender
#
# Use a loop to go through each student.
#
# For each student:
#
# Display the name, age, height, and score in table format.
#
# Stop.
